# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# ### Kantenerkennung mithilfe vom Sobel-Operator

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Lade das Bild
image_path = "/home/hermandi21/Mein-Schreibtisch/AIN6/2d-cv/puzzle_solver_2d/data/pzl_1_processed/pzl_1_004_front.jpg"
image = cv2.imread(image_path)
if image is None:
    print(f"Fehler beim Laden des Bildes: {image_path}")
else:
    # Konvertiere das Bild in Graustufen
    gray_image = np.dot(image[..., :3], [0.2989, 0.5870, 0.1140])
    gray_image = np.clip(gray_image, 0, 255).astype(np.uint8)

    # Sobel-Operator
    def sobel_operator(image):
        # Sobel-Kernel für x- und y-Richtung
        sobel_x = np.array([[-1, 0, 1],
                            [-2, 0, 2],
                            [-1, 0, 1]])
        
        sobel_y = np.array([[1, 2, 1],
                            [0, 0, 0],
                            [-1, -2, -1]])
        
        # Initialisiere das Ergebnisbild
        gradient_magnitude = np.zeros_like(image)

        # Wende den Sobel-Operator an
        for i in range(1, image.shape[0] - 1):
            for j in range(1, image.shape[1] - 1):
                gx = np.sum(sobel_x * image[i-1:i+2, j-1:j+2])
                gy = np.sum(sobel_y * image[i-1:i+2, j-1:j+2])
                gradient_magnitude[i, j] = np.sqrt(gx**2 + gy**2)
        
        return gradient_magnitude

    # Wende den Sobel-Operator auf das Graustufenbild an
    edges = sobel_operator(gray_image)
    # Normalisiere die Kantenstärke auf den Bereich [0, 255]
    edges = np.clip(edges, 0, 255).astype(np.uint8)
    # Zeige das Ergebnis an
    plt.imshow(edges, cmap='gray')
    plt.title("Sobel-Kantendetektion")
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### Kantenerkennung mithilfe von Canny-Kantendetektion

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Lade das Bild
image_path = "/home/hermandi21/Mein-Schreibtisch/AIN6/2d-cv/puzzle_solver_2d/data/pzl_1_processed/pzl_1_004_front.jpg"
image = cv2.imread(image_path)
if image is None:
    print(f"Fehler beim Laden des Bildes: {image_path}")
else:
    # Konvertiere das Bild in Graustufen
    gray_image = np.dot(image[..., :3], [0.2989, 0.5870, 0.1140])
    gray_image = np.clip(gray_image, 0, 255).astype(np.uint8)

    # Sobel-Operator
    def sobel_operator(image):
        sobel_x = np.array([[-1, 0, 1],
                            [-2, 0, 2],
                            [-1, 0, 1]])
        sobel_y = np.array([[1, 2, 1],
                            [0, 0, 0],
                            [-1, -2, -1]])
        gradient_magnitude = np.zeros_like(image)
        for i in range(1, image.shape[0] - 1):
            for j in range(1, image.shape[1] - 1):
                gx = np.sum(sobel_x * image[i-1:i+2, j-1:j+2])
                gy = np.sum(sobel_y * image[i-1:i+2, j-1:j+2])
                gradient_magnitude[i, j] = np.sqrt(gx**2 + gy**2)
        return gradient_magnitude

    # Canny-Kantendetektion ohne OpenCV
    def canny_edge_detection(image, low_threshold, high_threshold):
        gradient_magnitude = sobel_operator(image)
        suppressed = np.zeros_like(gradient_magnitude)
        angle = np.arctan2(np.gradient(image, axis=0), np.gradient(image, axis=1)) * 180 / np.pi
        angle[angle < 0] += 180
        for i in range(1, gradient_magnitude.shape[0] - 1):
            for j in range(1, gradient_magnitude.shape[1] - 1):
                q = 255
                r = 255
                if (0 <= angle[i, j] < 22.5) or (157.5 <= angle[i, j] <= 180):
                    q = gradient_magnitude[i, j + 1]
                    r = gradient_magnitude[i, j - 1]
                elif (22.5 <= angle[i, j] < 67.5):
                    q = gradient_magnitude[i + 1, j - 1]
                    r = gradient_magnitude[i - 1, j + 1]
                elif (67.5 <= angle[i, j] < 112.5):
                    q = gradient_magnitude[i + 1, j]
                    r = gradient_magnitude[i - 1, j]
                elif (112.5 <= angle[i, j] < 157.5):
                    q = gradient_magnitude[i - 1, j - 1]
                    r = gradient_magnitude[i + 1, j + 1]
                if (gradient_magnitude[i, j] >= q) and (gradient_magnitude[i, j] >= r):
                    suppressed[i, j] = gradient_magnitude[i, j]
                else:
                    suppressed[i, j] = 0
        strong_edges = (suppressed >= high_threshold)
        weak_edges = ((suppressed >= low_threshold) & (suppressed < high_threshold))
        edges_final = np.zeros_like(suppressed)
        edges_final[strong_edges] = 255
        for i in range(1, suppressed.shape[0] - 1):
            for j in range(1, suppressed.shape[1] - 1):
                if weak_edges[i, j]:
                    if ((strong_edges[i + 1, j - 1] or strong_edges[i + 1, j] or strong_edges[i + 1, j + 1]) or
                        (strong_edges[i, j - 1] or strong_edges[i, j + 1]) or
                        (strong_edges[i - 1, j - 1] or strong_edges[i - 1, j] or strong_edges[i - 1, j + 1])):
                        edges_final[i, j] = 255
        return edges_final

    # Wende die Canny-Kantendetektion an
    edges_canny = canny_edge_detection(gray_image, low_threshold=100, high_threshold=65)
    # Zeige das Ergebnis der Canny-Kantendetektion an
    plt.imshow(edges_canny, cmap='gray')
    plt.title("Canny-Kantendetektion")
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### Vergleich: Sobel vs. Canny Kantenoperator
#
# - **Sobel-Operator**:
#   - Einfaches Verfahren zur Kantenfindung.
#   - Nutzt Ableitungen (Gradienten), um Kanten in X- und Y-Richtung zu erkennen.
#   - Liefert oft dicke und ungenaue Kanten.
#   - Vorteil: schneller als Canny
#
# - **Canny-Algorithmus**:
#   - Fortgeschrittener Algorithmus für scharfe und präzise Kanten.
#   - Schritte:
#     1. Bild glätten (Rauschen entfernen).
#     2. Kantenrichtung und -stärke mit Sobel berechnen.
#     3. Nicht-maximale Unterdrückung (nur dünnste Kanten bleiben).
#     4. Doppelschwellenwert + Kantenverfolgung (nur wichtige Kanten bleiben).
#   - Vorteil: liefert saubere, dünne und zusammenhängende Kanten.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Lade das Bild
image_path = "/home/hermandi21/Mein-Schreibtisch/AIN6/2d-cv/puzzle_solver_2d/data/pzl_1_processed/pzl_1_004_front.jpg"
image = cv2.imread(image_path)
if image is None:
    print(f"Fehler beim Laden des Bildes: {image_path}")
else:
    # Konvertiere das Bild in Graustufen
    gray_image = np.dot(image[..., :3], [0.2989, 0.5870, 0.1140])
    gray_image = np.clip(gray_image, 0, 255).astype(np.uint8)

    # Roberts-Kantendetektion
    def roberts_operator(image):
        kernel_x = np.array([[1, 0], [0, -1]])
        kernel_y = np.array([[0, 1], [-1, 0]])
        edges_x = cv2.filter2D(image, -1, kernel_x)
        edges_y = cv2.filter2D(image, -1, kernel_y)
        return np.sqrt(edges_x**2 + edges_y**2)

    edges_roberts = roberts_operator(gray_image)

    # Prewitt-Kantendetektion
    def prewitt_operator(image):
        kernel_x = np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]])
        kernel_y = np.array([[1, 1, 1], [0, 0, 0], [-1, -1, -1]])
        edges_x = cv2.filter2D(image, -1, kernel_x)
        edges_y = cv2.filter2D(image, -1, kernel_y)
        return np.sqrt(edges_x**2 + edges_y**2)

    edges_prewitt = prewitt_operator(gray_image)

    # Sobel-Kantendetektion
    def sobel_operator(image):
        kernel_x = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])
        kernel_y = np.array([[1, 2, 1], [0, 0, 0], [-1, -2, -1]])
        edges_x = cv2.filter2D(image, -1, kernel_x)
        edges_y = cv2.filter2D(image, -1, kernel_y)
        return np.sqrt(edges_x**2 + edges_y**2)

    edges_sobel = sobel_operator(gray_image)

    # Laplacian of Gaussian (LoG)
    blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 1.0)
    edges_log = cv2.Laplacian(blurred_image, cv2.CV_64F)

    # Canny-Kantendetektion
    edges_canny = cv2.Canny(blurred_image, 15, 90)

    # Plot der Ergebnisse in zwei Spalten
    fig, axes = plt.subplots(3, 2, figsize=(12, 18))
    axes[0, 0].imshow(gray_image, cmap='gray')
    axes[0, 0].set_title("Originalbild")
    axes[0, 0].axis("off")

    axes[0, 1].imshow(edges_roberts, cmap='gray')
    axes[0, 1].set_title("Roberts-Kantendetektion")
    axes[0, 1].axis("off")

    axes[1, 0].imshow(edges_prewitt, cmap='gray')
    axes[1, 0].set_title("Prewitt-Kantendetektion")
    axes[1, 0].axis("off")

    axes[1, 1].imshow(edges_sobel, cmap='gray')
    axes[1, 1].set_title("Sobel-Kantendetektion")
    axes[1, 1].axis("off")

    axes[2, 0].imshow(edges_log, cmap='gray')
    axes[2, 0].set_title("Laplacian of Gaussian (LoG)")
    axes[2, 0].axis("off")

    axes[2, 1].imshow(edges_canny, cmap='gray')
    axes[2, 1].set_title("Canny-Kantendetektion (σ=1.0)")
    axes[2, 1].axis("off")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Canny-Kantendetektor
#
# - **Verwendet gerichtete Filter**:
#   - Auf mehreren Auflösungsebenen (multi-scale möglich).
#   - Ergebnisse werden zu einem gemeinsamen **Kantenbild ("edge map")** zusammengefügt.
#
# - **Ziel des Verfahrens**: Drei Qualitätskriterien gleichzeitig erfüllen:
#   1. **Wenige falsche Kantenmarkierungen** (hohe Genauigkeit).
#   2. **Gute Lokalisierung** (Kante genau an der richtigen Stelle).
#   3. **Nur eine Markierung pro Kante** (keine doppelten Linien).
#
# - **Technisch basiert auf einem Gradientenverfahren**:
#   - Nutzt die **erste Ableitung** (Gradient) zur Erkennung von Kanten.
#   - Verwendet zusätzlich **Nulldurchgänge der zweiten Ableitung** zur präzisen Lokalisierung.
#
# - **Glättung durch ein Filter mit einstellbarem Radius (σ)**:
#   - Stärkeres Glätten reduziert Rauschen und macht die Erkennung robuster.
#   - Typisch: Verwendung in einer **Single-Scale-Version** mit anpassbarem σ.
#
# - **Fazit**:
#   - Liefert **deutlich bessere Kantendetektion** als einfache Methoden wie Sobel.
#   - Wird daher auch in seiner einfachen Form oft bevorzugt.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# Lade das Bild
image_path = "../data/pzl_1_processed/pzl_1_001_front.jpg"
image = cv2.imread(image_path)
if image is None:
    print(f"Fehler beim Laden des Bildes: {image_path}")
else:
    # Konvertiere das Bild in Graustufen
    gray_image = np.dot(image[..., :3], [0.2989, 0.5870, 0.1140])
    gray_image = np.clip(gray_image, 0, 255).astype(np.uint8)

    # Wende den Canny-Kantendetektor mit verschiedenen Glättungsparametern an
    #sigma_values = [1, 2, 3]  # Beispielwerte für σ
    sigma_values = [0.05, 0.5, 0.75]  # Neue Werte für σ
    fig, axes = plt.subplots(1, len(sigma_values), figsize=(15, 5))

    for ax, sigma in zip(axes, sigma_values):
        # Glätte das Bild mit einem Gaussian-Filter
        blurred_image = cv2.GaussianBlur(gray_image, (5, 5), sigma)

        # Wende den Canny-Kantendetektor an
        edges_canny = cv2.Canny(blurred_image, 100, 200)

        # Zeige das Ergebnis
        ax.imshow(edges_canny, cmap='gray')
        ax.set_title(f"Canny mit σ={sigma}")
        ax.axis("off")

        # Speichere das Ergebnis
        output_dir = Path("../data/pzl_1_processed/canny_images/")
        output_dir.mkdir(parents=True, exist_ok=True)
        output_file = output_dir / f"pzl_1_001_front_canny_sigma_{sigma}.jpg"
        cv2.imwrite(str(output_file), edges_canny)
        print(f"Canny-Kantenerkennung gespeichert: {output_file}")

    plt.tight_layout()
    plt.show()
# Out:
# Canny-Kantenerkennung gespeichert: ../data/pzl_1_processed/canny_images/pzl_1_001_front_canny_sigma_0.05.jpg
# Canny-Kantenerkennung gespeichert: ../data/pzl_1_processed/canny_images/pzl_1_001_front_canny_sigma_0.5.jpg
# Canny-Kantenerkennung gespeichert: ../data/pzl_1_processed/canny_images/pzl_1_001_front_canny_sigma_0.75.jpg

# %%
# Lade das Bild mit Canny-Kantenerkennung für σ=0.05
image_path_canny = "../data/pzl_1_processed/canny_images/pzl_1_001_front_canny_sigma_0.05.jpg"
canny_image = cv2.imread(image_path_canny, cv2.IMREAD_GRAYSCALE)

if canny_image is None:
    print(f"Fehler beim Laden des Bildes: {image_path_canny}")
else:
    # Erstelle eine binäre Maske basierend auf den Kanten
    _, mask = cv2.threshold(canny_image, 1, 255, cv2.THRESH_BINARY)

    # Finde die Konturen im Maskenbild
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Erstelle ein leeres Bild für die Konturen
    contour_image = np.zeros_like(mask)

    # Zeichne die Konturen auf das leere Bild
    cv2.drawContours(contour_image, contours, -1, 255, thickness=1)

    # Schneide oben und unten jeweils 3 Pixel vom Bild ab
    contour_image_cropped = contour_image[4:-4, :]

    # Speichere das zugeschnittene Konturenbild
    cropped_output_path = "../data/pzl_1_processed/canny_images/pzl_1_001_front_contour_cropped.jpg"
    cv2.imwrite(cropped_output_path, contour_image_cropped)
    print(f"Zugeschnittenes Konturenbild gespeichert: {cropped_output_path}")

#zeige das zugeschnittene Konturenbild an
plt.imshow(contour_image_cropped, cmap='gray')
plt.title("Zugeschnittenes Konturenbild")
plt.axis("off")
plt.show()
# Out:
# Fehler beim Laden des Bildes: ../data/pzl_3_processed/canny_images/pzl_3_001_front_canny_sigma_0.05.jpg
# [ WARN:0@2303.138] global loadsave.cpp:268 findDecoder imread_('../data/pzl_3_processed/canny_images/pzl_3_001_front_canny_sigma_0.05.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 29
#      26     print(f"Zugeschnittenes Konturenbild gespeichert: {cropped_output_path}")
#      28 #zeige das zugeschnittene Konturenbild an
# ---> 29 plt.imshow(contour_image_cropped, cmap='gray')
#      30 plt.title("Zugeschnittenes Konturenbild")
#      31 plt.axis("off")
#
# NameError: name 'contour_image_cropped' is not defined
